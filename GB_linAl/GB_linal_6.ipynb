# %%
#1 Задание (теорема сложения)
#Найти вероятность выпадения 2 или 5 очков при подбрасывании игральной кости, на гранях 
#которой имеются соответственно 1,2,3,4,5 и 6 очков. 

p = 2/6
print(p)
# Out:
# 0.3333333333333333

# %%
#2 Задание (теорема умножения)
#Найти вероятность того, что при двух подбрасываниях той же самой игральной кости сначала выпадет 2, а затем 5.

p = 1/6 * 1/6
print(p)
# Out:
# 0.027777777777777776

# %%
#3 Задание 
#Найти вероятность выпадения 2 и 5 очков при двух подбрасываниях той же самой игральной игральной кости. 
#Обратите внимание на порядок выпадения костей!

p = 2/6 * 1/6
print(p)
# Out:
# 0.05555555555555555

# %%
#4 Задание  (Геометрическая вероятность +интервалы)
#На отрезке AB длиной 20 см наугад отметили точку C. Какова вероятность, что она находится 
#на расстоянии не более 9 см от точки А и не более 15 см от точки В?

p = 1 - 4/20 #= 16/20
print(p)
# Out:
# 0.8

# %%
#5 Задание. Телефонный номер состоит из 7 цифр. Какова вероятность, 
#что это номер 8882227?

p = 0.1 ** 7
print(p)
# Out:
# 1.0000000000000004e-07

# %%
#6 Задание. Набирая номер телефона, абонент забыл 2 последние цифры, и, помня только то, 
#что эти цифры различны и среди них нет нуля, стал набирать их наудачу. 
#Сколько вариантов ему надо перебрать, чтобы наверняка найти нужный номер? 
#Какова вероятность того, что он угадает номер с первого раза?

n = 63
p = 1/63
print(p)

#90 -9 - 9 -9 = 81
# Out:
# 0.015873015873015872

# %%
#Задание** (необязательное) 
#Чёрный куб покрасили снаружи белой краской, затем разрезали на 27 одинаковых маленьких кубиков и 
#как попало сложили из них большой куб. С какой вероятностью  все грани этого куба будут белыми?

# у каждого кубика есть 2 характеристики: грань снаружи и положение в большом кубе.
#1. положение в большом кубе:
# а) черный куб из центра должен оказаться в центре - 1/27
#б) 12 кубиков с ребер должны все оказаться на ребрах. это 12 независимых событий из 27.
#12/27 * 11/27 * 10/27 ... = 12! / 27^12
#в) 8 кубиков из вершин должны оказаться в вершинах
#8!/27^8
#г) 6 кубиков из центра граней должны оказаться в центре граней
#6!/27^6

#итого вероятность того, что все кубики будут на своих местах:
#p_pol = 12! * 8! * 6! / 27 ** 26

#2. грани снаружи:
#    а) любое положение - р = 1
#    б) всего 8 разных пар граней кубика могут быть наруже и каждая из комбинаций может быть 
#    повернутой и вверх ногами, итого всего 16 возможных положений кубика, нам подходят 2: р = 1/8 
#    в) всего 8 положений кубика, нам подходит только 1: р = 1/8
#    г) всего 6 положений кубика, нам подходит только 1: р = 1/6

#итого, вероятность того, что все кубики будут повернуты нужными гранями:
#p_storona = 1/8^12 * 1/8^8 * 1/6*6

#суммарная вероятность = p_pol + p_storona
